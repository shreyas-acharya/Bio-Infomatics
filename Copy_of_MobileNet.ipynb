# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyas-acharya/Bio-Informatics/blob/main/Copy_of_MobileNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Input, Conv2D, GlobalAveragePooling2D, ReLU, BatchNormalization, DepthwiseConv2D, Dense
from tensorflow.keras import Model

# %%
def depth_block(x, strides):    
    x = DepthwiseConv2D(3,strides=strides,padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    return x

def single_conv_block(x,filters):    
    x = Conv2D(filters, 1,use_bias=False)(x)
    x= BatchNormalization()(x)
    x = ReLU()(x)
    return x
def combo_layer(x,filters, strides):
    x = depth_block(x,strides)
    x = single_conv_block(x, filters)
    return x
def MobileNet(input_shape=(224,224,3),n_classes = 1000):    
    input = Input (input_shape)
    x = Conv2D(32,3,strides=(2,2),padding = 'same', use_bias=False) (input)
    x =  BatchNormalization()(x)
    x = ReLU()(x)    
    x = combo_layer(x,64, strides=(1,1))    
    x = combo_layer(x,128,strides=(2,2))
    x = combo_layer(x,128,strides=(1,1))
    x = combo_layer(x,256,strides=(2,2))
    x = combo_layer(x,256,strides=(1,1))
    x = combo_layer(x,512,strides=(2,2))
    for _ in range(5):
      x = combo_layer(x,512,strides=(1,1))     
    x = combo_layer(x,1024,strides=(2,2))
    x = combo_layer(x,1024,strides=(1,1))
    x = GlobalAveragePooling2D()(x)
    output = Dense(n_classes,activation='softmax')(x)
    model = Model(input, output)
    return model
n_classes = 1000
input_shape = (224,224,3)
model = MobileNet(input_shape,n_classes)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_16 (Conv2D)          (None, 112, 112, 32)      864
#
#  batch_normalization_28 (Bat  (None, 112, 112, 32)     128
#  chNormalization)
#
#  re_lu_28 (ReLU)             (None, 112, 112, 32)      0
#
#  depthwise_conv2d_13 (Depthw  (None, 112, 112, 32)     288
#  iseConv2D)
#
#  batch_normalization_29 (Bat  (None, 112, 112, 32)     128
#  chNormalization)
#
#  re_lu_29 (ReLU)             (None, 112, 112, 32)      0
#
#  conv2d_17 (Conv2D)          (None, 112, 112, 64)      2048
#
#  batch_normalization_30 (Bat  (None, 112, 112, 64)     256
#  chNormalization)
#
#  re_lu_30 (ReLU)             (None, 112, 112, 64)      0
#
#  depthwise_conv2d_14 (Depthw  (None, 56, 56, 64)       576
#  iseConv2D)
#
#  batch_normalization_31 (Bat  (None, 56, 56, 64)       256
#  chNormalization)
#
#  re_lu_31 (ReLU)             (None, 56, 56, 64)        0
#
#  conv2d_18 (Conv2D)          (None, 56, 56, 128)       8192
#
#  batch_normalization_32 (Bat  (None, 56, 56, 128)      512
#  chNormalization)
#
#  re_lu_32 (ReLU)             (None, 56, 56, 128)       0
#
#  depthwise_conv2d_15 (Depthw  (None, 56, 56, 128)      1152
#  iseConv2D)
#
#  batch_normalization_33 (Bat  (None, 56, 56, 128)      512
#  chNormalization)
#
#  re_lu_33 (ReLU)             (None, 56, 56, 128)       0
#
#  conv2d_19 (Conv2D)          (None, 56, 56, 128)       16384
#
#  batch_normalization_34 (Bat  (None, 56, 56, 128)      512
#  chNormalization)
#
#  re_lu_34 (ReLU)             (None, 56, 56, 128)       0
#
#  depthwise_conv2d_16 (Depthw  (None, 28, 28, 128)      1152
#  iseConv2D)
#
#  batch_normalization_35 (Bat  (None, 28, 28, 128)      512
#  chNormalization)
#
#  re_lu_35 (ReLU)             (None, 28, 28, 128)       0
#
#  conv2d_20 (Conv2D)          (None, 28, 28, 256)       32768
#
#  batch_normalization_36 (Bat  (None, 28, 28, 256)      1024
#  chNormalization)
#
#  re_lu_36 (ReLU)             (None, 28, 28, 256)       0
#
#  depthwise_conv2d_17 (Depthw  (None, 28, 28, 256)      2304
#  iseConv2D)
#
#  batch_normalization_37 (Bat  (None, 28, 28, 256)      1024
#  chNormalization)
#
#  re_lu_37 (ReLU)             (None, 28, 28, 256)       0
#
#  conv2d_21 (Conv2D)          (None, 28, 28, 256)       65536
#
#  batch_normalization_38 (Bat  (None, 28, 28, 256)      1024
#  chNormalization)
#
#  re_lu_38 (ReLU)             (None, 28, 28, 256)       0
#
#  depthwise_conv2d_18 (Depthw  (None, 14, 14, 256)      2304
#  iseConv2D)
#
#  batch_normalization_39 (Bat  (None, 14, 14, 256)      1024
#  chNormalization)
#
#  re_lu_39 (ReLU)             (None, 14, 14, 256)       0
#
#  conv2d_22 (Conv2D)          (None, 14, 14, 512)       131072
#
#  batch_normalization_40 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_40 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_19 (Depthw  (None, 14, 14, 512)      4608
#  iseConv2D)
#
#  batch_normalization_41 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_41 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_42 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_42 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_20 (Depthw  (None, 14, 14, 512)      4608
#  iseConv2D)
#
#  batch_normalization_43 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_43 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_24 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_44 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_44 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_21 (Depthw  (None, 14, 14, 512)      4608
#  iseConv2D)
#
#  batch_normalization_45 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_45 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_25 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_46 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_46 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_22 (Depthw  (None, 14, 14, 512)      4608
#  iseConv2D)
#
#  batch_normalization_47 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_47 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_26 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_48 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_48 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_23 (Depthw  (None, 14, 14, 512)      4608
#  iseConv2D)
#
#  batch_normalization_49 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_49 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_27 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_50 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_50 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_24 (Depthw  (None, 7, 7, 512)        4608
#  iseConv2D)
#
#  batch_normalization_51 (Bat  (None, 7, 7, 512)        2048
#  chNormalization)
#
#  re_lu_51 (ReLU)             (None, 7, 7, 512)         0
#
#  conv2d_28 (Conv2D)          (None, 7, 7, 1024)        524288
#
#  batch_normalization_52 (Bat  (None, 7, 7, 1024)       4096
#  chNormalization)
#
#  re_lu_52 (ReLU)             (None, 7, 7, 1024)        0
#
#  depthwise_conv2d_25 (Depthw  (None, 7, 7, 1024)       9216
#  iseConv2D)
#
#  batch_normalization_53 (Bat  (None, 7, 7, 1024)       4096
#  chNormalization)
#
#  re_lu_53 (ReLU)             (None, 7, 7, 1024)        0
#
#  conv2d_29 (Conv2D)          (None, 7, 7, 1024)        1048576
#
#  batch_normalization_54 (Bat  (None, 7, 7, 1024)       4096
#  chNormalization)
#
#  re_lu_54 (ReLU)             (None, 7, 7, 1024)        0
#
#  global_average_pooling2d_1   (None, 1024)             0
#  (GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1000)              1025000
#
# =================================================================
# Total params: 4,253,864
# Trainable params: 4,231,976
# Non-trainable params: 21,888
# _________________________________________________________________
